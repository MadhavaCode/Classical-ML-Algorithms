# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.ensemble import AdaBoostClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.svm import SVC
from sklearn.datasets import make_classification

# %%
x, y = make_classification(n_samples = 1000, n_features = 20, random_state = 0)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 0)

# %%
logis = LogisticRegression(max_iter = 1000)
knn = KNeighborsClassifier(n_neighbors = 5)
tree = DecisionTreeClassifier(max_depth = 5)
svm = SVC(probability = True)

# %%
adaboost = AdaBoostClassifier(estimator = DecisionTreeClassifier(max_depth = 1), n_estimators = 50, learning_rate = 0.5, random_state = 0)

# %%
dictionary_models = {"Logistic Regression" : logis, "KNN" : knn, "Decision Tree" : tree, "SVM" : svm, "AdaBoost" : adaboost}

# %%
for model_name, model in dictionary_models.items():
    model.fit(x_train, y_train)
    y_pred = model.predict(x_test)
    accuracy = accuracy_score(y_test, y_pred)
    print(f"{model_name} accuracy: {accuracy}")
# Out:
# Logistic Regression accuracy: 0.965
# KNN accuracy: 0.935
# Decision Tree accuracy: 0.955
# SVM accuracy: 0.955
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# AdaBoost accuracy: 0.965

# %%
accuracy_results = {}

# %%
for model_name, model in dictionary_models.items():
    model.fit(x_train, y_train)
    y_pred = model.predict(x_test)
    accuracy = accuracy_score(y_test, y_pred)
    accuracy_results[model_name] = accuracy

    print(f"{model_name} accuracy: {np.round(accuracy, 2)}")
# Out:
# Logistic Regression accuracy: 0.96
# KNN accuracy: 0.94
# Decision Tree accuracy: 0.95
# SVM accuracy: 0.96
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# AdaBoost accuracy: 0.96

# %%
plt.figure(figsize = (10, 5))
plt.bar(accuracy_results.keys(), accuracy_results.values(), color = ["blue", "green", "red", "purple"])

plt.xlabel("Model Name")
plt.ylabel("Accuracy")
plt.title("Model Comparison")
plt.show()

# %%
df = pd.read_csv("/content/breast-cancer.csv")

# %%
df
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %%
x = df.iloc[:, 2:].values
y = df.iloc[:, 1].values

# %%
logis = LogisticRegression(max_iter = 1000)
knn = KNeighborsClassifier(n_neighbors = 5)
tree = DecisionTreeClassifier(max_depth = 5)
svm = SVC(probability = True)

# %%
adaboost = AdaBoostClassifier(estimator = DecisionTreeClassifier(max_depth = 1), n_estimators = 50, learning_rate = 0.5, random_state = 0)

# %%
dictionary_models = {"Logistic Regression" : logis, "KNN" : knn, "Decision Tree" : tree, "SVM" : svm, "AdaBoost" : adaboost}

# %%
for model_name, model in dictionary_models.items():
    model.fit(x_train, y_train)
    y_pred = model.predict(x_test)
    accuracy = accuracy_score(y_test, y_pred)
    print(f"{model_name} accuracy: {accuracy}")
# Out:
# Logistic Regression accuracy: 0.965
# KNN accuracy: 0.935
# Decision Tree accuracy: 0.955
# SVM accuracy: 0.955
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# AdaBoost accuracy: 0.965

# %%
accuracy_results = {}

# %%
for model_name, model in dictionary_models.items():
    model.fit(x_train, y_train)
    y_pred = model.predict(x_test)
    accuracy = accuracy_score(y_test, y_pred)
    accuracy_results[model_name] = accuracy

    print(f"{model_name} accuracy: {np.round(accuracy, 2)}")
# Out:
# Logistic Regression accuracy: 0.96
# KNN accuracy: 0.94
# Decision Tree accuracy: 0.96
# SVM accuracy: 0.96
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# AdaBoost accuracy: 0.96

# %%
plt.figure(figsize = (10, 5))
plt.bar(accuracy_results.keys(), accuracy_results.values(), color = ["blue", "green", "red", "purple"])

plt.legend()

plt.xlabel("Model Name")
plt.ylabel("Accuracy")
plt.title("Model Comparison")
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# **Adaboost for regression**

# %%
from sklearn.ensemble import AdaBoostRegressor
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor
from sklearn.datasets import fetch_california_housing

# %%
housing = fetch_california_housing()

# %%
x, y = housing.data, housing.target

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 0)

# %%
linear_regression = LinearRegression()
decision_tree = DecisionTreeRegressor()
svr = SVR()
random_forest = RandomForestRegressor(n_estimators = 100, random_state = 0)

# %%
dictionary_models = {"Linear Regression" : linear_regression, "Decision Tree" : decision_tree, "SVR" : svr, "Random Forest" : random_forest}

# %%
for model_name, model in dictionary_models.items():
    model.fit(x_train, y_train)
    y_pred = model.predict(x_test)
    mse = mean_squared_error(y_test, y_pred)
    print(f"{model_name} MSE: {mse}")
# Out:
# Linear Regression MSE: 0.5289841670367247
# Decision Tree MSE: 0.539211614989559
# SVR MSE: 1.3260916573306467
# Random Forest MSE: 0.2633220342809945

# %%
accuracy_results = {}

# %%
for model_name, model in dictionary_models.items():
    model.fit(x_train, y_train)
    y_pred = model.predict(x_test)
    mse = mean_squared_error(y_test, y_pred)
    accuracy_results[model_name] = mse

    print(f"{model_name} MSE: {np.round(mse, 2)}")
# Out:
# Linear Regression MSE: 0.53
# Decision Tree MSE: 0.55
# SVR MSE: 1.33
# Random Forest MSE: 0.26

# %%
plt.figure(figsize = (10, 5))
plt.bar(accuracy_results.keys(), accuracy_results.values(), color = ["blue", "green", "red", "purple"])

plt.xlabel("Model Name")
plt.ylabel("MSE")
plt.title("Model Comparison")
plt.show()

# %% [markdown]
# **Implment Adaboost on multiclassification**
